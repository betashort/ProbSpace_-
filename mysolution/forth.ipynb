# %%
import os
import platform 
import gc

import re
import numpy as np
import pandas as pd

pd.options.display.max_columns = None
pd.options.display.max_rows = None


import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import mean_squared_error, mean_absolute_error

import lightgbm as lgb

import warnings 
warnings.filterwarnings('ignore')

# %%
X = pd.read_csv('./input/train_data.csv')
X_test = pd.read_csv('./input/test_data.csv')
test_id = X_test['id']

# %%
y = X['salary']
X = X.drop(['salary', 'id'], axis=1)
X_test = X_test.drop(['id'], axis=1)

# %%
X.dtypes
# Out:
# position            int64
# age                 int64
# area               object
# sex                 int64
# partner             int64
# num_child           int64
# education           int64
# service_length      int64
# study_time        float64
# commute           float64
# overtime          float64
# dtype: object

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## salaryと相関が強い
# 1. position
# - age
# - service_length
# - commute

# %%
def create_feature(df):
    '''
    #歳による役職
    df['MA'] = df['age'].apply(lambda x: 1 if (x >= 26) else 0)
    df['GM'] =  df['age'].apply(lambda x: 1 if (x >= 31) else 0)
    df['not_noname'] = df['age'].apply(lambda x: 1 if (x <= 31) else 0)
    '''
    
    '''
    #歳による役職
    df['position_age'] = 0
    df['position_age'][(df['age'] >=18) & (df['age'] <=25)] = 0
    df['position_age'][(df['age'] >=26) & (df['age'] <=31)] = 1
    df['position_age'][(df['age'] >=32) & (df['age'] <=36)] = 2
    df['position_age'][(df['age'] >=37)& (df['age'] <=58)] = 3
    df['position_age'][(df['age'] >=59)] = 4
    '''
    
    #家族の数(自分を含む)
    df['family'] = 1 + df['partner'] + df['num_child']
    
    #総通勤時間
    df['total_commute'] = df['service_length'] * (((df['commute']*2) * 25) * 12)
    
    #月当たり：会社以外の時間
    df['time_for_company'] = df['overtime'] + ((df['commute']*2) * 25)
    
    #入社した歳
    df['age_enter'] = df['age'] - df['service_length']
    
    #===卒業した歳===
    age_graduate = {0:18, 1:20, 2:22, 3:24, 4:27}
    df['age_graduate'] = df['education'].map(age_graduate)
    
    #新卒?中途?
    df['fresh_mid'] = df['age_enter'] - df['age_graduate']
    
    #月当たり：自由な時間
    #土日休みとする
    df['free_time'] = 24*31 - ( 9*25 + (df['commute']*2)*25 + df['overtime'])
    
    #自分だけの時間
    df['aman_free_time'] = df['free_time'] / df['family']
    
    #勉強に費やしている時間の割合
    df['study_per_freetime'] = df['study_time'] / df['aman_free_time']
    
    
    return df

# %%
X = create_feature(X)
X_test = create_feature(X_test)

# %% [markdown]
# ## Labeling

# %%
def labeling(X, X_test, y):
    col_category = []
    for i in X.columns:
        if X[i].dtype == 'object':
            
            # ======== ラベルエンコーディング ==========
            le = LabelEncoder()
            X[f'{i}_label'] = le.fit_transform(X[i])
            X_test[f'{i}_label'] = le.transform(X_test[i])
            
            col_category.append(f'{i}_label')
            
            '''
            # ========= ランキング ==============
            maps = pd.concat([X, np.exp(y)], axis=1).groupby(i)['salary'].mean().sort_values(ascending=False).index
            maps = pd.DataFrame({i: maps, 'rank': np.linspace(0, maps.shape[0]-1, maps.shape[0])})
            maps = dict(maps.to_dict(orient='split')['data'])
            X[f'{i}_rank'] = X[i].map(maps)
            X_test[f'{i}_rank'] = X_test[i].map(maps)
            
            col_category.append(f'{i}_rank')
            
            
            # ===== targeting =======
            data_tmp = pd.DataFrame({i:X[i], 'target':y})
            target_mean = data_tmp.groupby(i)['target'].mean()
            
            X_test[f'{i}_target'] = X_test[i].map(target_mean)
            #X_test[f'{c}_target_log'] = np.log(X_test[c].map(target_mean))
            
            tmp = np.repeat(np.nan, X.shape[0])
            
            kf = KFold(n_splits=4, shuffle=True, random_state=72)
            
            for idx_1, idx_2 in kf.split(X):
                target_mean = data_tmp.iloc[idx_1].groupby(i)['target'].mean()
                tmp[idx_2] = X[i].iloc[idx_2].map(target_mean)
                X[f'{i}_target'] = tmp
                #X[f'{c}_target_log'] = np.log(tmp)
            
            col_category.append(f'{i}_target')
            #new_col_category.append(f'{c}_target_log')
            '''
            # ===== 元のラベルの削除 =====
            X = X.drop(i, axis=1)
            X_test = X_test.drop(i, axis=1)
            
    return X, X_test, col_category

# %%
X, X_test, col_category = labeling(X, X_test, y)

# %%
print('X.shape', X.shape,
      '\nX_test.shape', X_test.shape,
     )
# Out:
# X.shape (21000, 20)
# X_test.shape (9000, 20)

# %%
X.head()
# Out:
#    position  age  sex  partner  num_child  education  service_length  \
# 0         1   44    2        1          2          1              24
# 1         2   31    1        0          0          0              13
# 2         2   36    1        0          0          2              14
# 3         0   22    2        0          0          0               4
# 4         0   25    2        0          0          1               5
#
#    study_time  commute  overtime  family  total_commute  time_for_company  \
# 0         2.0      1.6       9.2       4        23040.0              89.2
# 1         9.0      0.7      12.4       1         5460.0              47.4
# 2         4.0      0.4      16.9       1         3360.0              36.9
# 3         3.0      0.4       6.1       1          960.0              26.1
# 4         3.0      0.2       4.9       1          600.0              14.9
#
#    age_enter  age_graduate  fresh_mid  free_time  aman_free_time  \
# 0         20            20          0      429.8          107.45
# 1         18            18          0      471.6          471.60
# 2         22            22          0      482.1          482.10
# 3         18            18          0      492.9          492.90
# 4         20            20          0      504.1          504.10
#
#    study_per_freetime  area_label
# 0            0.018613          24
# 1            0.019084          10
# 2            0.008297          14
# 3            0.006086          26
# 4            0.005951          46

# %%
y = np.log(y)

# %%
params = {
    'objective': 'fair',
    'metric': 'fair',
    'learning_rate': 0.01,
    'max_depth': -1,
    'num_leaves': 255,
    'max_bin': 255,
    'colsample_bytree': 0.8,
    'subsample': 0.8,
    'nthread': -1,
    'bagging_freq': 1,
    'verbose': -1,
    'seed': 1,
}

# %%
def lightgbms(X, X_test, y, params, random=0):
    
    NFOLDS = 5
    
    folds = KFold(n_splits=NFOLDS, random_state=random, shuffle=True)

    preds = pd.DataFrame()
    train_preds = pd.DataFrame()

    columns = X.columns
    splits = folds.split(X, y)

    y_preds = np.zeros(X_test.shape[0])
    y_oof = np.zeros(X.shape[0])

    score = 0
    scores = []

    feature_importances = pd.DataFrame()
    feature_importances['feature'] = columns

    for fold_n, (train_index, val_index) in enumerate(splits):
        # split train, Valid
        X_train, X_val = X[columns].iloc[train_index], X[columns].iloc[val_index]
        y_train, y_val = y.iloc[train_index], y.iloc[val_index]

        '''
        LightGBM
        '''
        dtrain = lgb.Dataset(X_train, y_train)
        dval = lgb.Dataset(X_val, y_val)

        clf = lgb.train(params,
                        dtrain,
                        5000,
                        valid_sets=[dtrain, dval],
                        verbose_eval=1000,
                        categorical_feature=col_category,
                        early_stopping_rounds=500)
        
        
        feature_importances[f'fold_{fold_n + 1}'] = clf.feature_importance()
        
        '''
        LightGBM
        '''
        # stack
        y_pred_val = clf.predict(X_val)
        y_oof[val_index] = y_pred_val
    
            
        print(f"Fold {fold_n + 1} | rmse: {mean_absolute_error(np.exp(y_val),np.exp( y_pred_val))}")
        
        score += mean_absolute_error(np.exp(y_val),np.exp( y_pred_val)) / NFOLDS
        scores.append(mean_absolute_error(np.exp(y_val),np.exp( y_pred_val)))

        y_preds += clf.predict(X_test) / NFOLDS

        train_preds[f"Fold {fold_n + 1}"] = clf.predict(X)

        preds[f"Fold {fold_n + 1}"] = clf.predict(X_test)

        del X_train, X_val, y_train, y_val
        gc.collect()
    print(f"\nMean RSME = {score}")

    return y_oof, y_preds, scores, feature_importances

# %%
# %%time
## === Seed ===
_, y_preds1, _, feature_importances = lightgbms(X, X_test, y, params, 1)
_, y_preds2, _, _ = lightgbms(X, X_test, y, params, 2)
_, y_preds3, _, _ = lightgbms(X, X_test, y, params, 3)
_, y_preds4, _, _ = lightgbms(X, X_test, y, params, 4)
_, y_preds5, _, _ = lightgbms(X, X_test, y, params, 5)
# Out:
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000929505	valid_1's fair: 0.00372141
# Early stopping, best iteration is:
# [670]	training's fair: 0.00137741	valid_1's fair: 0.00370841
# Fold 1 | rmse: 23.309961111083908
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000918522	valid_1's fair: 0.00387996
# Early stopping, best iteration is:
# [695]	training's fair: 0.00132365	valid_1's fair: 0.00386838
# Fold 2 | rmse: 23.205766983084843
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000918968	valid_1's fair: 0.00360123
# Early stopping, best iteration is:
# [608]	training's fair: 0.00148796	valid_1's fair: 0.00356452
# Fold 3 | rmse: 22.5577859311841
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000924828	valid_1's fair: 0.00363562
# Early stopping, best iteration is:
# [678]	training's fair: 0.00135928	valid_1's fair: 0.00362502
# Fold 4 | rmse: 23.13828050334323
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000918136	valid_1's fair: 0.00375229
# Early stopping, best iteration is:
# [780]	training's fair: 0.00119364	valid_1's fair: 0.0037406
# Fold 5 | rmse: 23.337765897125887
#
# Mean RSME = 23.109912085164392
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.00093651	valid_1's fair: 0.00352297
# Early stopping, best iteration is:
# [714]	training's fair: 0.00131768	valid_1's fair: 0.00350445
# Fold 1 | rmse: 22.596858033945864
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000926672	valid_1's fair: 0.00377794
# Early stopping, best iteration is:
# [762]	training's fair: 0.00122952	valid_1's fair: 0.00376469
# Fold 2 | rmse: 22.774351836971274
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000914788	valid_1's fair: 0.00369902
# Early stopping, best iteration is:
# [627]	training's fair: 0.00144155	valid_1's fair: 0.00366814
# Fold 3 | rmse: 23.042015296199498
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000924262	valid_1's fair: 0.00372808
# Early stopping, best iteration is:
# [617]	training's fair: 0.00147178	valid_1's fair: 0.00371197
# Fold 4 | rmse: 23.581314155424522
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000920331	valid_1's fair: 0.00375657
# Early stopping, best iteration is:
# [690]	training's fair: 0.00133565	valid_1's fair: 0.00373398
# Fold 5 | rmse: 23.421392064799807
#
# Mean RSME = 23.083186277468194
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000929069	valid_1's fair: 0.00366017
# Early stopping, best iteration is:
# [673]	training's fair: 0.00137293	valid_1's fair: 0.00364206
# Fold 1 | rmse: 22.583864630760512
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000913758	valid_1's fair: 0.00381374
# Early stopping, best iteration is:
# [684]	training's fair: 0.00133834	valid_1's fair: 0.00378392
# Fold 2 | rmse: 23.690240233898724
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000922821	valid_1's fair: 0.00361829
# Early stopping, best iteration is:
# [711]	training's fair: 0.0013044	valid_1's fair: 0.00359684
# Fold 3 | rmse: 22.696985194744393
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000927085	valid_1's fair: 0.00362364
# Early stopping, best iteration is:
# [699]	training's fair: 0.0013253	valid_1's fair: 0.00359784
# Fold 4 | rmse: 23.003142464517897
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000920823	valid_1's fair: 0.00387304
# Early stopping, best iteration is:
# [791]	training's fair: 0.00117741	valid_1's fair: 0.00386662
# Fold 5 | rmse: 23.56554632570643
#
# Mean RSME = 23.10795576992559
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000910222	valid_1's fair: 0.00384664
# Early stopping, best iteration is:
# [599]	training's fair: 0.00148958	valid_1's fair: 0.00381817
# Fold 1 | rmse: 23.515566891980477
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000928209	valid_1's fair: 0.00368905
# Early stopping, best iteration is:
# [718]	training's fair: 0.00129981	valid_1's fair: 0.00367532
# Fold 2 | rmse: 23.232542714088513
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000914121	valid_1's fair: 0.00377094
# Early stopping, best iteration is:
# [715]	training's fair: 0.00128598	valid_1's fair: 0.00375519
# Fold 3 | rmse: 23.689496797877776
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000925436	valid_1's fair: 0.00379584
# Early stopping, best iteration is:
# [757]	training's fair: 0.00123388	valid_1's fair: 0.00377658
# Fold 4 | rmse: 22.979909128028766
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000935966	valid_1's fair: 0.00351777
# Early stopping, best iteration is:
# [684]	training's fair: 0.00136459	valid_1's fair: 0.00350284
# Fold 5 | rmse: 22.399325223207565
#
# Mean RSME = 23.16336815103662
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000915966	valid_1's fair: 0.00375742
# Early stopping, best iteration is:
# [669]	training's fair: 0.00136343	valid_1's fair: 0.00373527
# Fold 1 | rmse: 23.196328382465804
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000926351	valid_1's fair: 0.00370652
# Early stopping, best iteration is:
# [659]	training's fair: 0.00139359	valid_1's fair: 0.00368594
# Fold 2 | rmse: 22.923001540803085
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000920762	valid_1's fair: 0.00361715
# Early stopping, best iteration is:
# [620]	training's fair: 0.00145987	valid_1's fair: 0.00358764
# Fold 3 | rmse: 22.401435917248172
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000921961	valid_1's fair: 0.00390277
# Early stopping, best iteration is:
# [717]	training's fair: 0.00129128	valid_1's fair: 0.00389318
# Fold 4 | rmse: 23.604443277228135
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000922747	valid_1's fair: 0.00366543
# Early stopping, best iteration is:
# [674]	training's fair: 0.00137137	valid_1's fair: 0.0036514
# Fold 5 | rmse: 23.61703044490821
#
# Mean RSME = 23.148447912530678
# CPU times: user 21min, sys: 11.9 s, total: 21min 11s
# Wall time: 6min 21s

# %%
pred_list = [y_preds1,
             y_preds2,
             y_preds3,
             y_preds4,
             y_preds5]
pred = np.zeros(X_test.shape[0])
for i in pred_list:
    pred += np.exp(i).astype(int) / 5
    
pred = pred.astype(int)

# %%
feature_importances['average'] = feature_importances[[f'fold_{fold_n + 1}' for fold_n in range(5)]].mean(axis=1)

plt.figure(figsize=(16, 16))
sns.barplot(data=feature_importances.sort_values(by='average', ascending=False).head(20), x='average', y='feature');
plt.title('250 TOP feature importance over {} folds average'.format(10))
#plt.savefig('TOP250_feature_importance.png')
plt.show()

# %%
sub = pd.DataFrame({'id': test_id, 'y': pred})

# %%
sub.head()
# Out:
#    id    y
# 0   0  515
# 1   1  269
# 2   2  206
# 3   3  155
# 4   4  288

# %%
sub.to_csv('sub_lgb_forth.csv', index=None)
