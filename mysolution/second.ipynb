# %%
import os
import platform 
import gc

import re
import numpy as np
import pandas as pd

pd.options.display.max_columns = None
pd.options.display.max_rows = None


import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import mean_squared_error, mean_absolute_error

import lightgbm as lgb

import warnings 
warnings.filterwarnings('ignore')

# %%
X = pd.read_csv('./input/train_data.csv')
X_test = pd.read_csv('./input/test_data.csv')
test_id = X_test['id']

# %%
y = X['salary']
X = X.drop(['salary', 'id'], axis=1)
X_test = X_test.drop(['id'], axis=1)

# %%
X.dtypes
# Out:
# position            int64
# age                 int64
# area               object
# sex                 int64
# partner             int64
# num_child           int64
# education           int64
# service_length      int64
# study_time        float64
# commute           float64
# overtime          float64
# dtype: object

# %%
X = X.astype({'position':object, 'sex': object, 'partner': object, 'education': object})
X_test = X_test.astype({'position':object, 'sex': object, 'partner': object, 'education': object})

# %%
X.dtypes
# Out:
# position           object
# age                 int64
# area               object
# sex                object
# partner            object
# num_child           int64
# education          object
# service_length      int64
# study_time        float64
# commute           float64
# overtime          float64
# dtype: object

# %% [markdown]
# # Feature Engineering

# %%
def create_feature(df):
    #position-age
    df['MA'] = df['age'].apply(lambda x: 1 if (x >= 26) else 0)
    df['GM'] =  df['age'].apply(lambda x: 1 if (x >= 31) else 0)
    df['not_noname'] = df['age'].apply(lambda x: 1 if (x <= 31) else 0)
    
    df['position_age'] = 0
    df['position_age'][(df['age'] >=18) & (df['age'] <=25)] = 0
    df['position_age'][(df['age'] >=26) & (df['age'] <=31)] = 1
    df['position_age'][(df['age'] >=32) & (df['age'] <=36)] = 2
    df['position_age'][(df['age'] >=37)& (df['age'] <=58)] = 3
    df['position_age'][(df['age'] >=59)] = 4
    return df

# %%
X = create_feature(X)
X_test = create_feature(X_test)

# %% [markdown]
# ## Labeling

# %%
def labeling(X, X_test, y):
    col_category = []
    for i in X.columns:
        if X[i].dtype == 'object':
            
            # ======== ラベルエンコーディング ==========
            le = LabelEncoder()
            X[f'{i}_label'] = le.fit_transform(X[i])
            X_test[f'{i}_label'] = le.transform(X_test[i])
            
            col_category.append(f'{i}_label')
            
            
            # ========= ランキング ==============
            maps = pd.concat([X, np.exp(y)], axis=1).groupby(i)['salary'].mean().sort_values(ascending=False).index
            maps = pd.DataFrame({i: maps, 'rank': np.linspace(0, maps.shape[0]-1, maps.shape[0])})
            maps = dict(maps.to_dict(orient='split')['data'])
            X[f'{i}_rank'] = X[i].map(maps)
            X_test[f'{i}_rank'] = X_test[i].map(maps)
            
            col_category.append(f'{i}_rank')
            
            
            # ===== targeting =======
            data_tmp = pd.DataFrame({i:X[i], 'target':y})
            target_mean = data_tmp.groupby(i)['target'].mean()
            
            X_test[f'{i}_target'] = X_test[i].map(target_mean)
            #X_test[f'{c}_target_log'] = np.log(X_test[c].map(target_mean))
            
            tmp = np.repeat(np.nan, X.shape[0])
            
            kf = KFold(n_splits=4, shuffle=True, random_state=72)
            
            for idx_1, idx_2 in kf.split(X):
                target_mean = data_tmp.iloc[idx_1].groupby(i)['target'].mean()
                tmp[idx_2] = X[i].iloc[idx_2].map(target_mean)
                X[f'{i}_target'] = tmp
                #X[f'{c}_target_log'] = np.log(tmp)
            
            col_category.append(f'{i}_target')
            #new_col_category.append(f'{c}_target_log')
            
            # ===== 元のラベルの削除 =====
            X = X.drop(i, axis=1)
            X_test = X_test.drop(i, axis=1)
            
    return X, X_test, col_category

# %%
X, X_test, col_category = labeling(X, X_test, y)

# %%
print('X.shape', X.shape,
      '\nX_test.shape', X_test.shape,
     )
# Out:
# X.shape (21000, 25)
# X_test.shape (9000, 25)

# %%
X.head()
# Out:
#    age  num_child  service_length  study_time  commute  overtime  MA  GM  \
# 0   44          2              24         2.0      1.6       9.2   1   1
# 1   31          0              13         9.0      0.7      12.4   1   1
# 2   36          0              14         4.0      0.4      16.9   1   1
# 3   22          0               4         3.0      0.4       6.1   0   0
# 4   25          0               5         3.0      0.2       4.9   0   0
#
#    not_noname  position_age  position_label  position_rank  position_target  \
# 0           0             3               1            3.0       353.052757
# 1           1             1               2            2.0       464.199322
# 2           0             2               2            2.0       464.577931
# 3           1             0               0            4.0       220.888384
# 4           1             0               0            4.0       220.888384
#
#    area_label  area_rank  area_target  sex_label  sex_rank  sex_target  \
# 0          24       36.0   394.344582          1       0.0  356.000041
# 1          10       11.0   369.951268          0       1.0  364.886034
# 2          14        8.0   357.888184          0       1.0  366.979616
# 3          26       44.0   406.042014          1       0.0  355.623862
# 4          46        0.0   351.506991          1       0.0  355.623862
#
#    partner_label  partner_rank  partner_target  education_label  \
# 0              1           0.0      386.011628                1
# 1              0           1.0      335.696862                0
# 2              0           1.0      337.331617                2
# 3              0           1.0      335.696862                0
# 4              0           1.0      335.696862                1
#
#    education_rank  education_target
# 0             3.0        324.580923
# 1             4.0        309.005587
# 2             2.0        384.643186
# 3             4.0        309.005587
# 4             3.0        324.608579

# %%
y = np.log(y)

# %%
params = {
    'objective': 'fair',
    'metric': 'fair',
    'learning_rate': 0.01,
    'max_depth': -1,
    'num_leaves': 255,
    'max_bin': 255,
    'colsample_bytree': 0.8,
    'subsample': 0.8,
    'nthread': -1,
    'bagging_freq': 1,
    'verbose': -1,
    'seed': 1,
}

# %%
def lightgbms(X, X_test, y, params, random=0):
    
    NFOLDS = 5
    
    folds = KFold(n_splits=NFOLDS, random_state=random, shuffle=True)

    preds = pd.DataFrame()
    train_preds = pd.DataFrame()

    columns = X.columns
    splits = folds.split(X, y)

    y_preds = np.zeros(X_test.shape[0])
    y_oof = np.zeros(X.shape[0])

    score = 0
    scores = []

    feature_importances = pd.DataFrame()
    feature_importances['feature'] = columns

    for fold_n, (train_index, val_index) in enumerate(splits):
        # split train, Valid
        X_train, X_val = X[columns].iloc[train_index], X[columns].iloc[val_index]
        y_train, y_val = y.iloc[train_index], y.iloc[val_index]

        '''
        LightGBM
        '''
        dtrain = lgb.Dataset(X_train, y_train)
        dval = lgb.Dataset(X_val, y_val)

        clf = lgb.train(params,
                        dtrain,
                        5000,
                        valid_sets=[dtrain, dval],
                        verbose_eval=1000,
                        categorical_feature=col_category,
                        early_stopping_rounds=500)
        
        
        feature_importances[f'fold_{fold_n + 1}'] = clf.feature_importance()
        
        '''
        LightGBM
        '''
        # stack
        y_pred_val = clf.predict(X_val)
        y_oof[val_index] = y_pred_val
    
            
        print(f"Fold {fold_n + 1} | rmse: {mean_absolute_error(np.exp(y_val),np.exp( y_pred_val))}")
        
        score += mean_absolute_error(np.exp(y_val),np.exp( y_pred_val)) / NFOLDS
        scores.append(mean_absolute_error(np.exp(y_val),np.exp( y_pred_val)))

        y_preds += clf.predict(X_test) / NFOLDS

        train_preds[f"Fold {fold_n + 1}"] = clf.predict(X)

        preds[f"Fold {fold_n + 1}"] = clf.predict(X_test)

        del X_train, X_val, y_train, y_val
        gc.collect()
    print(f"\nMean RSME = {score}")

    return y_oof, y_preds, scores, feature_importances

# %%
# %%time
## === Seed ===
_, y_preds1, _, feature_importances = lightgbms(X, X_test, y, params, 1)
_, y_preds2, _, _ = lightgbms(X, X_test, y, params, 2)
_, y_preds3, _, _ = lightgbms(X, X_test, y, params, 3)
_, y_preds4, _, _ = lightgbms(X, X_test, y, params, 4)
_, y_preds5, _, _ = lightgbms(X, X_test, y, params, 5)
# Out:
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000970101	valid_1's fair: 0.00398854
# Early stopping, best iteration is:
# [679]	training's fair: 0.00142838	valid_1's fair: 0.00396157
# Fold 1 | rmse: 25.088993396402724
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000962594	valid_1's fair: 0.00417051
# Early stopping, best iteration is:
# [568]	training's fair: 0.00165241	valid_1's fair: 0.00412882
# Fold 2 | rmse: 25.056821411303368
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000979045	valid_1's fair: 0.00373246
# Early stopping, best iteration is:
# [610]	training's fair: 0.00158508	valid_1's fair: 0.00369599
# Fold 3 | rmse: 23.8547205852445
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000973871	valid_1's fair: 0.00384043
# Early stopping, best iteration is:
# [589]	training's fair: 0.00161984	valid_1's fair: 0.00380553
# Fold 4 | rmse: 24.345354683719528
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000971035	valid_1's fair: 0.00393862
# Early stopping, best iteration is:
# [592]	training's fair: 0.00160963	valid_1's fair: 0.00389813
# Fold 5 | rmse: 24.71900685399851
#
# Mean RSME = 24.612979386133723
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000985354	valid_1's fair: 0.00370834
# Early stopping, best iteration is:
# [691]	training's fair: 0.00143111	valid_1's fair: 0.00368899
# Fold 1 | rmse: 24.332979104761698
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000964792	valid_1's fair: 0.00398685
# Early stopping, best iteration is:
# [555]	training's fair: 0.00168634	valid_1's fair: 0.00394446
# Fold 2 | rmse: 24.13634243313309
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000961273	valid_1's fair: 0.00396489
# Early stopping, best iteration is:
# [591]	training's fair: 0.0016014	valid_1's fair: 0.00392077
# Fold 3 | rmse: 24.68594665905888
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000974835	valid_1's fair: 0.0039678
# Early stopping, best iteration is:
# [591]	training's fair: 0.00161693	valid_1's fair: 0.00393388
# Fold 4 | rmse: 24.962474709078897
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000962542	valid_1's fair: 0.00403646
# Early stopping, best iteration is:
# [583]	training's fair: 0.00161644	valid_1's fair: 0.00400784
# Fold 5 | rmse: 25.157410591841575
#
# Mean RSME = 24.65503069957483
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000973321	valid_1's fair: 0.003854
# Early stopping, best iteration is:
# [559]	training's fair: 0.00168407	valid_1's fair: 0.00381413
# Fold 1 | rmse: 24.05281740465851
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000967394	valid_1's fair: 0.00399344
# Early stopping, best iteration is:
# [584]	training's fair: 0.0016192	valid_1's fair: 0.00396127
# Fold 2 | rmse: 25.037585513881496
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000979166	valid_1's fair: 0.0038351
# Early stopping, best iteration is:
# [572]	training's fair: 0.0016684	valid_1's fair: 0.00378802
# Fold 3 | rmse: 24.15223237469013
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000969996	valid_1's fair: 0.00389726
# Early stopping, best iteration is:
# [631]	training's fair: 0.00152827	valid_1's fair: 0.00386889
# Fold 4 | rmse: 24.74562345166248
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000954692	valid_1's fair: 0.00414447
# Early stopping, best iteration is:
# [638]	training's fair: 0.00149311	valid_1's fair: 0.00411615
# Fold 5 | rmse: 25.150968857866133
#
# Mean RSME = 24.62784552055175
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000966015	valid_1's fair: 0.00401605
# Early stopping, best iteration is:
# [555]	training's fair: 0.00168906	valid_1's fair: 0.00395704
# Fold 1 | rmse: 24.892365213220547
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000977557	valid_1's fair: 0.00387836
# Early stopping, best iteration is:
# [681]	training's fair: 0.00143771	valid_1's fair: 0.00383963
# Fold 2 | rmse: 24.67409179234162
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.00096495	valid_1's fair: 0.00396774
# Early stopping, best iteration is:
# [679]	training's fair: 0.00142676	valid_1's fair: 0.00394127
# Fold 3 | rmse: 25.027810851096774
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000971396	valid_1's fair: 0.004009
# Early stopping, best iteration is:
# [626]	training's fair: 0.00153792	valid_1's fair: 0.00397919
# Fold 4 | rmse: 24.482026533009396
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000977791	valid_1's fair: 0.00372054
# Early stopping, best iteration is:
# [635]	training's fair: 0.00152986	valid_1's fair: 0.00369046
# Fold 5 | rmse: 23.81664533904954
#
# Mean RSME = 24.57858794574358
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000966836	valid_1's fair: 0.00390502
# Early stopping, best iteration is:
# [681]	training's fair: 0.00142553	valid_1's fair: 0.00388148
# Fold 1 | rmse: 24.661518430931388
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000963015	valid_1's fair: 0.00405346
# Early stopping, best iteration is:
# [561]	training's fair: 0.00166717	valid_1's fair: 0.00399879
# Fold 2 | rmse: 24.7869843064983
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000974117	valid_1's fair: 0.00386818
# Early stopping, best iteration is:
# [592]	training's fair: 0.0016139	valid_1's fair: 0.00383026
# Fold 3 | rmse: 24.144659655476232
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000965741	valid_1's fair: 0.00403253
# Early stopping, best iteration is:
# [729]	training's fair: 0.00134208	valid_1's fair: 0.00400789
# Fold 4 | rmse: 24.62631360811207
# Training until validation scores don't improve for 500 rounds.
# [1000]	training's fair: 0.000978536	valid_1's fair: 0.003871
# Early stopping, best iteration is:
# [593]	training's fair: 0.00162137	valid_1's fair: 0.00382577
# Fold 5 | rmse: 24.937927315865927
#
# Mean RSME = 24.631480663376784
# CPU times: user 20min 34s, sys: 10.1 s, total: 20min 45s
# Wall time: 5min 58s

# %%
pred_list = [y_preds1,
             y_preds2,
             y_preds3,
             y_preds4,
             y_preds5]
pred = np.zeros(X_test.shape[0])
for i in pred_list:
    pred += np.exp(i).astype(int) / 5
    
pred = pred.astype(int)

# %%
feature_importances['average'] = feature_importances[[f'fold_{fold_n + 1}' for fold_n in range(5)]].mean(axis=1)

plt.figure(figsize=(16, 16))
sns.barplot(data=feature_importances.sort_values(by='average', ascending=False).head(20), x='average', y='feature');
plt.title('250 TOP feature importance over {} folds average'.format(10))
#plt.savefig('TOP250_feature_importance.png')
plt.show()

# %%
sub = pd.DataFrame({'id': test_id, 'y': pred})

# %%
sub.head()
# Out:
#    id    y
# 0   0  514
# 1   1  293
# 2   2  207
# 3   3  159
# 4   4  294

# %%
sub.to_csv('sub_lgb_second.csv', index=None)
